# %% [markdown]
# В цьому домашньому завданні відпрацюємо з вами знання, отримані в модулі зі статистики.
#
# **Завдання 1.** Ми обговорили з Вами на лекції, що велика літера Сігма грецького алфавіту позначає в математиці суму. Знайдіть з використанням Python $\Sigma x$, $\Sigma x^2$, та $\Sigma (x-1)^2$ для наступного набору даних:
# `1 3 4`
# Виведіть результат кожного обчислення на екран.

# %%
data = [1, 3, 4]

sum_x = sum(data)
print(f"Сума Σx: {sum_x}")

sum_x_squared = sum([x**2 for x in data])
print(f"Сума Σx2: {sum_x_squared}")

sum_x_minus_1_squared = sum([(x-1)**2 for x in data])
print(f"Сума Σ(x−1)2: {sum_x_minus_1_squared}")
# Out:
# Сума Σx: 8
# Сума Σx2: 26
# Сума Σ(x−1)2: 13

# %% [markdown]
# **Завдання 2.** Ми зібрали дані про суму покупок в гривнях 20ма випадково обраними клієнтами в нашому магазині (всього клієнтів у нас більше) за минулий місяць. Вони представлені в змінній `sum_purchases`. Знайдіть **вибіркове середнє** для цих даних кожним з зазначених методів:
#
#   2.1. без використання жодних бібліотек, користуючись тільки Python.
#   2.2. використовуючи відповідний метод бібліотеки `numpy`.
#
#   Виведіть результат обчислень в кожному з випадків на екран та порівняйте результати. Вони співпадають?

# %%
sum_purchases = [ 316,  493,  367,  153,  224,  121,  322,  450,  196,  397,  281,
  239,  484,  124,  223,  448,  432,  255, 4310, 3524]

# %%
n_sum_purchases = len(sum_purchases)
mean_sum_purchases = sum(sum_purchases)/n_sum_purchases
print("Вибіркове середнє без використання бібліотек:", mean_sum_purchases)
# Out:
# Вибіркове середнє без використання бібліотек: 667.95

# %%
import numpy as np

mean = np.mean(sum_purchases)
print("Вибіркове середнє використовуючи бібліотеку numpy:", mean)
# Out:
# Вибіркове середнє використовуючи бібліотеку numpy: 667.95

# %%
if mean_sum_purchases == mean:
    print("Результат співпадає")
else:
    print("Результат не співпадає")
# Out:
# Результат співпадає

# %% [markdown]
# **Завдання 3.** Для того ж набору даних в змінній `sum_purchases` обчисліть **медіану** кожним з зазначених методів:
#
#   3.1. без використання жодних бібліотек, користуючись тільки Python.
#   3.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат обчислень в кожному з випадків на екран. Порівняйте результати зі значенням вибіркового середнього. Напишіть коментар, для яких задач ви б використовували вибіркове середнє, а для яких - медіану?

# %%
median = (sorted(sum_purchases)[len(sum_purchases)//2-1] + sorted(sum_purchases)[len(sum_purchases)//2])/2
median_np = np.median(sum_purchases)
print("Медіана без використання бібліотек:", median)
print("Медіана використовуючи бібліотеку numpy:", median_np)
if median == median_np:
    print("Результат співпадає")
else:
    print("Результат не співпадає")

# Вибіркове середнє краще використовувати, коли дані не містять значних викидів і мають симетричний розподіл.
# Медіану варто використовувати, коли дані мають асиметричний розподіл або містять викиди, оскільки вона дає більш точне уявлення про типове значення.
# У нашому випадку, сума покупок містить великі значення (4310, 3524), які є викидами.медіана (319.0) значно нижча за середнє (667.95) через їх присутність.
# Ці викиди значно зміщують середнє значення вгору, роблячи його менш репрезентативним для більшості клієнтів.
# Out:
# Медіана без використання бібліотек: 319.0
# Медіана використовуючи бібліотеку numpy: 319.0
# Результат співпадає

# %% [markdown]
# **Завдання 4**. Обчислість стандартне відхилення наведеної вибірки в змінній `sum_purchases` кожним з зазначених методів:
#
#   4.1. без використання жодних бібліотек, користуючись тільки Python.
#   4.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат обчислень в кожному з випадків на екран.

# %%
mean_purchases = sum(sum_purchases) / len(sum_purchases)
sum_sq_diff = sum([(x - mean_purchases)**2 for x in sum_purchases])

std_dev_python = (sum_sq_diff / (len(sum_purchases) - 1))**0.5
print(f"Вибіркове стандартне відхилення (чистий Python): {std_dev_python:.2f}")

import numpy as np

std_dev_numpy = np.std(sum_purchases, ddof=1)
print(f"Вибіркове стандартне відхилення (numpy): {std_dev_numpy:.2f}")
# Out:
# Вибіркове стандартне відхилення (чистий Python): 1124.54
# Вибіркове стандартне відхилення (numpy): 1124.54

# %% [markdown]
# **Завдання 5**. Ми провели дослідження віку студентів-першокурсників. Виявилось, що
# - 10 студентів мають вік 16 років
# - 25 студентів - 17 років
# - 20 студентів - 18 років
# - 2 студенти - 20 років
#
# Обчислість середнє значення для цієї вибірки будь-яким способом - на чистому Python або з numpy - та виведіть результат на екран.

# %%
ages = [16, 17, 18, 20]
counts = [10, 25, 20, 2]

sum_of_ages = sum(age * count for age, count in zip(ages, counts))
total_students = sum(counts)
mean_age = sum_of_ages / total_students
print(f"Середнє значення віку (чистий Python): {mean_age:.2f}")
# Out:
# Середнє значення віку (чистий Python): 17.28

# %% [markdown]
# **Завдання 6**. Крім даних про суму покупок, ми зібрали ще дані про кількість відвідувань кожного з кожного покупця, які знаходяться в змінній `visits`. Обчисліть коефіцієнт кореляції Пірсона для суми покупок і кількості відвідувань кожним з зазначених методів:
#
#   6.1. без використання жодних бібліотек, користуючись тільки Python.
#   6.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат на екран. Проаналізуйте результат.
#
# Виведіть додатково графік розсіювання викликавши код нижче і зробіть заключення, чи варто щось змінити при підрахунку кореляції, аби коефіцієнт Пірсона показував коректну оцінку лінійної залежності?

# %%
visits = [ 6,  2, 10,  3,  9,  9,  2,  3,  6,  6, 10,  2,  5, 10,  3,  5,  4,
        7,  4,  2]

# %%
import numpy as np
import matplotlib.pyplot as plt

def mean(data):
    return sum(data) / len(data)

def pearson_manual(x, y):
    mu_x = mean(x)
    mu_y = mean(y)
    numerator = sum((xi - mu_x) * (yi - mu_y) for xi, yi in zip(x, y))
    sum_sq_x = sum((xi - mu_x) ** 2 for xi in x)
    sum_sq_y = sum((yi - mu_y) ** 2 for yi in y)
    return numerator / ((sum_sq_x ** 0.5) * (sum_sq_y ** 0.5))

print(f"Manual Pearson: {pearson_manual(sum_purchases, visits):.4f}")
print(f"Numpy Pearson: {np.corrcoef(sum_purchases, visits)[0, 1]:.4f}")

plt.scatter(sum_purchases, visits)
plt.xlabel('Сума покупок')
plt.ylabel('Візити')
plt.title('Графік розсіювання')
plt.show()
# Out:
# Manual Pearson: -0.3027
# Numpy Pearson: -0.3027

# %%
import matplotlib.pyplot as plt

plt.scatter(sum_purchases, visits)
plt.title('Scatter Plot of Purchases vs. Visits')
plt.xlabel('Sum of Purchases')
plt.ylabel('Number of Visits');

# %% [markdown]
# **Завдання 7**. В попередньому завданні ми помітили, що викиди нам заважають отримати "правдиве" значення кореляції. Давайте вилучимо записи, які відповідають значенням з викидами в сумі покупок і обчисліть коеф. кореляції. Для цього поставте `threshold`, який дорінює середньому значенню + 2 стандартних вдіхилля суми покупок і всі значення, які більше за нього, будемо вважати викидами (є і інші правила для визначення викидів - з ним и познайомимось пізніше).
#
# Вилучіть значення з обох масивів і обчисліть коеф. кореляції Пірсона з допомогою `numpy` для кількості візитів і суми покупок без записів-викидів. Виведіть результат на екран, побудуйте діаграму розсіювання і проаналізуйте результат: що можемо сказати про залежність в даних?

# %%
import numpy as np
import matplotlib.pyplot as plt

sum_purchases = np.array([316, 493, 367, 153, 224, 121, 322, 450, 196, 397,
                          281, 239, 484, 124, 223, 448, 432, 255, 4310, 3524])
visits = np.array([6, 2, 10, 3, 9, 9, 2, 3, 6, 6, 10, 2, 5, 10, 3, 5, 4, 7, 4, 2])

mean_val = np.mean(sum_purchases)
std_val = np.std(sum_purchases)
threshold = mean_val + 2 * std_val

print(f"Середнє значення: {mean_val:.2f}")
print(f"Стандартне відхилення: {std_val:.2f}")
print(f"Поріг відсікання (Threshold): {threshold:.2f}")


mask = sum_purchases <= threshold

clean_sum = sum_purchases[mask]
clean_visits = visits[mask]

print(f"Кількість записів до очистки: {len(sum_purchases)}")
print(f"Кількість записів після очистки: {len(clean_sum)}")

clean_corr = np.corrcoef(clean_sum, clean_visits)[0, 1]
print(f"\nКоефіцієнт кореляції (без викидів): {clean_corr:.4f}")

plt.figure(figsize=(10, 6))

plt.scatter(clean_sum, clean_visits, color='green', s=100, label='Основні дані')

plt.scatter(sum_purchases[~mask], visits[~mask], color='red', marker='x', s=100, label='Вилучені викиди')

plt.title(f'Залежність: Сума покупок vs Візити (Кореляція: {clean_corr:.2f})')
plt.xlabel('Сума покупок ($)')
plt.ylabel('Кількість візитів')
plt.axvline(x=threshold, color='gray', linestyle='--', label='Поріг відсікання')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Середнє значення: 667.95
# Стандартне відхилення: 1096.07
# Поріг відсікання (Threshold): 2860.09
# Кількість записів до очистки: 20
# Кількість записів після очистки: 18
#
# Коефіцієнт кореляції (без викидів): -0.3685
